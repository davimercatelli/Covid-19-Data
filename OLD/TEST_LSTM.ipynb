# %%
import pandas as pd
import numpy as np
import datetime as dt
import math

import matplotlib.ticker as ticker
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

import plotly.graph_objects as go
import plotly.express as px

import tensorflow as tf
from tensorflow import keras

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

plt.rcParams.update({'font.size': 16})

# %%
np.random.seed(7)

# %%
pd.set_option("display.precision", 5)
pd.set_option('display.max_rows', 15)

# %%
url = 'https://covid.ourworldindata.org/data/owid-covid-data.csv'

# %%
df = pd.read_csv(url)
df['date'] = pd.to_datetime(df['date'])
df['location'] = df['location'].replace(['United States'],'United_States')
df['location'] = df['location'].replace(['United Kingdom'],'United_Kingdom')

# %% [markdown]
# ### Start date to analysis: 2020-03-01

# %%
df = df.loc[:,['date', 'location', 'total_cases', 'total_deaths', 'new_cases', 'new_deaths']]
df = df[(df['date'] > '2020-03-01')]
df = df.sort_values(by=['total_cases'], ascending=True)

# %% [markdown]
# ### Brazil Cases

# %%
dfBrazil = df[df['location'] == 'Brazil']
dfBrazil = dfBrazil.sort_values(by='date', ascending=True)
dfBrazil.reset_index(drop=True, inplace=True)
dfBrazil
# Out:
#           date location  total_cases  total_deaths  new_cases  new_deaths
# 0   2020-03-02   Brazil          2.0           0.0        0.0         0.0
# 1   2020-03-03   Brazil          2.0           0.0        0.0         0.0
# 2   2020-03-04   Brazil          2.0           0.0        0.0         0.0
# 3   2020-03-05   Brazil          3.0           0.0        1.0         0.0
# 4   2020-03-06   Brazil          8.0           0.0        5.0         0.0
# ..         ...      ...          ...           ...        ...         ...
# 139 2020-07-19   Brazil    2074860.0       78772.0    28532.0       921.0
# 140 2020-07-20   Brazil    2098389.0       79488.0    23529.0       716.0
# 141 2020-07-21   Brazil    2118646.0       80120.0    20257.0       632.0
# 142 2020-07-22   Brazil    2159654.0       81487.0    41008.0      1367.0
# 143 2020-07-23   Brazil    2227514.0       82771.0    67860.0      1284.0
#
# [144 rows x 6 columns]

# %%
dfBrazil.plot(x='date', y=['total_deaths','total_cases'], figsize=(19.20,10.80))

plt.ylabel('Number of Cases')
plt.title('Total deaths [BRAZIL]')

ax = plt.gca()
ax.xaxis.set_major_locator(mdates.DayLocator(interval=10))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m'))
plt.ticklabel_format(style='plain', axis='y', scilimits=(0,0))
plt.gcf().autofmt_xdate()

plt.grid()
plt.show()

# %% [markdown]
# ### New deaths [Brazil]

# %%
dfBrazil.plot(x='date', y='new_deaths', figsize=(19.20,10.80))

plt.ylabel('Number of Cases')
plt.title('New deaths per day [BRAZIL]')

ax = plt.gca()
ax.xaxis.set_major_locator(mdates.DayLocator(interval=10))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m'))
plt.ticklabel_format(style='plain', axis='y', scilimits=(0,0))
plt.gcf().autofmt_xdate()

plt.grid()
plt.show()

# %% [markdown]
# ### LSTM Network for Regression

# %%
dfPredict = dfBrazil.loc[:,['date','new_deaths']]
dfPredict = dfPredict[(dfBrazil['new_deaths'] > 200)]
dfPredict = dfPredict.sort_values(by='date', ascending=True)
dfPredict['date'] = dfPredict['date'].dt.year.astype('str')+'-'+dfPredict['date'].dt.month.astype('str')+'-'+dfPredict['date'].dt.day.astype('str')
dfPredict.reset_index(drop=True, inplace=True)
dfPredict
# Out:
#          date  new_deaths
# 0   2020-4-15       204.0
# 1   2020-4-16       204.0
# 2   2020-4-18       217.0
# 3   2020-4-19       206.0
# 4   2020-4-24       407.0
# ..        ...         ...
# 89  2020-7-19       921.0
# 90  2020-7-20       716.0
# 91  2020-7-21       632.0
# 92  2020-7-22      1367.0
# 93  2020-7-23      1284.0
#
# [94 rows x 2 columns]

# %%
dfDeaths = dfPredict.drop(['date'],axis=1)

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dfDeaths)

# %%
train_size = int(len(dataset)*0.75)
test_size = len(dataset) - train_size
train = dataset[0:train_size,:]
test = dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 70 24

# %%
def create_dataset(dataset, lookBack=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-lookBack-1):
        a = dataset[i:(i+lookBack),0]
        dataX.append(a)
        dataY.append(dataset[i+lookBack,0])
    return np.array(dataX), np.array(dataY)

# %%
lookBack = 1
trainX, trainY = create_dataset(train, lookBack)
testX, testY = create_dataset(test, lookBack)

# %%
trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
model = keras.Sequential()
model.add(keras.layers.LSTM(128, input_shape=((1, lookBack))))
model.add(keras.layers.Dense(1))
optAdam = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])

# %%
history = model.fit(trainX, trainY, epochs=100, batch_size=10, validation_split=0.01, verbose=1, shuffle=False)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 137ms/step - loss: 0.2645 - mse: 0.2645 - val_loss: 0.4314 - val_mse: 0.4314
# Epoch 2/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2206 - mse: 0.2206 - val_loss: 0.3639 - val_mse: 0.3639
# Epoch 3/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.1812 - mse: 0.1812 - val_loss: 0.3014 - val_mse: 0.3014
# Epoch 4/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.1463 - mse: 0.1463 - val_loss: 0.2442 - val_mse: 0.2442
# Epoch 5/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.1161 - mse: 0.1161 - val_loss: 0.1926 - val_mse: 0.1926
# Epoch 6/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0910 - mse: 0.0910 - val_loss: 0.1474 - val_mse: 0.1474
# Epoch 7/100
# 7/7 [==============================] - 0s 36ms/step - loss: 0.0712 - mse: 0.0712 - val_loss: 0.1094 - val_mse: 0.1094
# Epoch 8/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0571 - mse: 0.0571 - val_loss: 0.0791 - val_mse: 0.0791
# Epoch 9/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0481 - mse: 0.0481 - val_loss: 0.0566 - val_mse: 0.0566
# Epoch 10/100
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0434 - mse: 0.0434 - val_loss: 0.0412 - val_mse: 0.0412
# Epoch 11/100
# 7/7 [==============================] - 0s 51ms/step - loss: 0.0416 - mse: 0.0416 - val_loss: 0.0314 - val_mse: 0.0314
# Epoch 12/100
# 7/7 [==============================] - 0s 41ms/step - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0259 - val_mse: 0.0259
# Epoch 13/100
# 7/7 [==============================] - 0s 45ms/step - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0232 - val_mse: 0.0232
# Epoch 14/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0414 - mse: 0.0414 - val_loss: 0.0223 - val_mse: 0.0223
# Epoch 15/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0412 - mse: 0.0412 - val_loss: 0.0224 - val_mse: 0.0224
# Epoch 16/100
# 7/7 [==============================] - 0s 68ms/step - loss: 0.0409 - mse: 0.0409 - val_loss: 0.0229 - val_mse: 0.0229
# Epoch 17/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0405 - mse: 0.0405 - val_loss: 0.0235 - val_mse: 0.0235
# Epoch 18/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0401 - mse: 0.0401 - val_loss: 0.0239 - val_mse: 0.0239
# Epoch 19/100
# 7/7 [==============================] - 0s 43ms/step - loss: 0.0397 - mse: 0.0397 - val_loss: 0.0240 - val_mse: 0.0240
# Epoch 20/100
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0394 - mse: 0.0394 - val_loss: 0.0240 - val_mse: 0.0240
# Epoch 21/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0390 - mse: 0.0390 - val_loss: 0.0238 - val_mse: 0.0238
# Epoch 22/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0387 - mse: 0.0387 - val_loss: 0.0235 - val_mse: 0.0235
# Epoch 23/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0384 - mse: 0.0384 - val_loss: 0.0232 - val_mse: 0.0232
# Epoch 24/100
# 7/7 [==============================] - 0s 44ms/step - loss: 0.0381 - mse: 0.0381 - val_loss: 0.0229 - val_mse: 0.0229
# Epoch 25/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0379 - mse: 0.0379 - val_loss: 0.0226 - val_mse: 0.0226
# Epoch 26/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0376 - mse: 0.0376 - val_loss: 0.0223 - val_mse: 0.0223
# Epoch 27/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0373 - mse: 0.0373 - val_loss: 0.0221 - val_mse: 0.0221
# Epoch 28/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0371 - mse: 0.0371 - val_loss: 0.0219 - val_mse: 0.0219
# Epoch 29/100
# 7/7 [==============================] - 0s 48ms/step - loss: 0.0368 - mse: 0.0368 - val_loss: 0.0217 - val_mse: 0.0217
# Epoch 30/100
# 7/7 [==============================] - 0s 52ms/step - loss: 0.0366 - mse: 0.0366 - val_loss: 0.0216 - val_mse: 0.0216
# Epoch 31/100
# 7/7 [==============================] - 0s 32ms/step - loss: 0.0364 - mse: 0.0364 - val_loss: 0.0214 - val_mse: 0.0214
# Epoch 32/100
# 7/7 [==============================] - 0s 44ms/step - loss: 0.0362 - mse: 0.0362 - val_loss: 0.0212 - val_mse: 0.0212
# Epoch 33/100
# 7/7 [==============================] - 0s 43ms/step - loss: 0.0360 - mse: 0.0360 - val_loss: 0.0211 - val_mse: 0.0211
# Epoch 34/100
# 7/7 [==============================] - 0s 43ms/step - loss: 0.0358 - mse: 0.0358 - val_loss: 0.0209 - val_mse: 0.0209
# Epoch 35/100
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0356 - mse: 0.0356 - val_loss: 0.0207 - val_mse: 0.0207
# Epoch 36/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0355 - mse: 0.0355 - val_loss: 0.0206 - val_mse: 0.0206
# Epoch 37/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0353 - mse: 0.0353 - val_loss: 0.0204 - val_mse: 0.0204
# Epoch 38/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0351 - mse: 0.0351 - val_loss: 0.0203 - val_mse: 0.0203
# Epoch 39/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0350 - mse: 0.0350 - val_loss: 0.0201 - val_mse: 0.0201
# Epoch 40/100
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0349 - mse: 0.0349 - val_loss: 0.0200 - val_mse: 0.0200
# Epoch 41/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0347 - mse: 0.0347 - val_loss: 0.0199 - val_mse: 0.0199
# Epoch 42/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0346 - mse: 0.0346 - val_loss: 0.0198 - val_mse: 0.0198
# Epoch 43/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0345 - mse: 0.0345 - val_loss: 0.0197 - val_mse: 0.0197
# Epoch 44/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0344 - mse: 0.0344 - val_loss: 0.0195 - val_mse: 0.0195
# Epoch 45/100
# 7/7 [==============================] - 0s 44ms/step - loss: 0.0343 - mse: 0.0343 - val_loss: 0.0194 - val_mse: 0.0194
# Epoch 46/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0342 - mse: 0.0342 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 47/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0341 - mse: 0.0341 - val_loss: 0.0192 - val_mse: 0.0192
# Epoch 48/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0340 - mse: 0.0340 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 49/100
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0339 - mse: 0.0339 - val_loss: 0.0191 - val_mse: 0.0191
# Epoch 50/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0339 - mse: 0.0339 - val_loss: 0.0190 - val_mse: 0.0190
# Epoch 51/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0338 - mse: 0.0338 - val_loss: 0.0189 - val_mse: 0.0189
# Epoch 52/100
# 7/7 [==============================] - 0s 35ms/step - loss: 0.0338 - mse: 0.0338 - val_loss: 0.0188 - val_mse: 0.0188
# Epoch 53/100
# 7/7 [==============================] - 0s 40ms/step - loss: 0.0337 - mse: 0.0337 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 54/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0336 - mse: 0.0336 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 55/100
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0336 - mse: 0.0336 - val_loss: 0.0186 - val_mse: 0.0186
# Epoch 56/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0336 - mse: 0.0336 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 57/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0335 - mse: 0.0335 - val_loss: 0.0185 - val_mse: 0.0185
# Epoch 58/100
# 7/7 [==============================] - 0s 38ms/step - loss: 0.0335 - mse: 0.0335 - val_loss: 0.0184 - val_mse: 0.0184
# Epoch 59/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0334 - mse: 0.0334 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 60/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0334 - mse: 0.0334 - val_loss: 0.0183 - val_mse: 0.0183
# Epoch 61/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0334 - mse: 0.0334 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 62/100
# 7/7 [==============================] - 0s 49ms/step - loss: 0.0334 - mse: 0.0334 - val_loss: 0.0182 - val_mse: 0.0182
# Epoch 63/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0333 - mse: 0.0333 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 64/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0333 - mse: 0.0333 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 65/100
# 7/7 [==============================] - 0s 43ms/step - loss: 0.0333 - mse: 0.0333 - val_loss: 0.0181 - val_mse: 0.0181
# Epoch 66/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0333 - mse: 0.0333 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 67/100
# 7/7 [==============================] - 0s 23ms/step - loss: 0.0333 - mse: 0.0333 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 68/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0332 - mse: 0.0332 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 69/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0332 - mse: 0.0332 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 70/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0332 - mse: 0.0332 - val_loss: 0.0179 - val_mse: 0.0179
# Epoch 71/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0332 - mse: 0.0332 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 72/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0332 - mse: 0.0332 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 73/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0332 - mse: 0.0332 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 74/100
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0332 - mse: 0.0332 - val_loss: 0.0178 - val_mse: 0.0178
# Epoch 75/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0332 - mse: 0.0332 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 76/100
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0332 - mse: 0.0332 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 77/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 78/100
# 7/7 [==============================] - 0s 46ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 79/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0176 - val_mse: 0.0176
# Epoch 80/100
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0176 - val_mse: 0.0176
# Epoch 81/100
# 7/7 [==============================] - 0s 39ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0176 - val_mse: 0.0176
# Epoch 82/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0176 - val_mse: 0.0176
# Epoch 83/100
# 7/7 [==============================] - 0s 42ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0176 - val_mse: 0.0176
# Epoch 84/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0175 - val_mse: 0.0175
# Epoch 85/100
# 7/7 [==============================] - 0s 47ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0175 - val_mse: 0.0175
# Epoch 86/100
# 7/7 [==============================] - 0s 33ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0175 - val_mse: 0.0175
# Epoch 87/100
# 7/7 [==============================] - 0s 27ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0175 - val_mse: 0.0175
# Epoch 88/100
# 7/7 [==============================] - 0s 29ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0175 - val_mse: 0.0175
# Epoch 89/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0175 - val_mse: 0.0175
# Epoch 90/100
# 7/7 [==============================] - 0s 34ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0175 - val_mse: 0.0175
# Epoch 91/100
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 92/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 93/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 94/100
# 7/7 [==============================] - 0s 25ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 95/100
# 7/7 [==============================] - 0s 26ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 96/100
# 7/7 [==============================] - 0s 24ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 97/100
# 7/7 [==============================] - 0s 37ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 98/100
# 7/7 [==============================] - 0s 44ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0174 - val_mse: 0.0174
# Epoch 99/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0173 - val_mse: 0.0173
# Epoch 100/100
# 7/7 [==============================] - 0s 30ms/step - loss: 0.0331 - mse: 0.0331 - val_loss: 0.0173 - val_mse: 0.0173

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend();

# %%
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %%
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 229.67 RMSE
# Test Score: 298.44 RMSE

# %%
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[lookBack:len(trainPredict)+lookBack, :] = trainPredict

# %%
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(lookBack*2)+1:len(dataset)-1, :] = testPredict

# %%
fig = plt.gcf()
fig.set_size_inches(19.20,10.80)

plt.ylabel('Number of Cases')
plt.title('Forecast to new deaths per day [BRAZIL]')

plt.plot(scaler.inverse_transform(dataset))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.gca().legend(('New Deaths','Train','Test'))

plt.grid()
plt.show()
