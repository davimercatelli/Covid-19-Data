# %% [markdown]
# # Using Python tools for a analysis of COVID-19 data

# %% [markdown]
# # ARIMA method to forecast

# %% [markdown]
# #### Source: https://www.digitalocean.com/community/tutorials/a-guide-to-time-series-forecasting-with-arima-in-python-3

# %%
import warnings
warnings.filterwarnings('ignore')

import itertools
import pandas as pd
import numpy as np
import statsmodels.api as sm

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker

import seaborn as sns

from sklearn.preprocessing import MinMaxScaler

from dateutil.relativedelta import relativedelta
from scipy.optimize import minimize

import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs

from itertools import product 
from tqdm import tqdm_notebook

# %matplotlib inline

# %%
mpl.rcParams['font.size'] = 15.0

# %%
pd.set_option("display.precision", 5)
pd.set_option('display.max_rows', 15)

# %% [markdown]
# ### <span style="color:red">Analysis of the last N days</span>

# %%
Ndays = '150days'

# %% [markdown]
# ### <span style="color:red">Day range for matplotlib</span>

# %%
Ninterval = 7

# %%
url = 'https://covid.ourworldindata.org/data/owid-covid-data.csv'

# %%
#filename = '/home/davi/Documents/Python/Covid-19-Data/owid-covid-data.csv'

# %%
df = pd.read_csv(url)
# df = pd.read_csv(filename)
df['date'] = pd.to_datetime(df['date'])
df['location'] = df['location'].replace(['United States'],'United_States')
df['location'] = df['location'].replace(['United Kingdom'],'United_Kingdom')

# %%
df = df.loc[:,['date', 'location', 'total_cases', 'total_deaths', 'new_cases', 'new_deaths']]
df = df[df['date'] > pd.to_datetime("today") - pd.to_timedelta(Ndays)]
df = df.sort_values(by=['total_cases'], ascending=True)

# %% [markdown]
# # Number of cases and deaths in World

# %%
dfWorld = df[df['location'] == 'World']
dfWorld = dfWorld.sort_values(by='date', ascending=True)
dfWorld = dfWorld.loc[:,['date', 'total_cases', 'total_deaths', 'new_cases', 'new_deaths']]
dfWorld.reset_index(drop=True, inplace=True)
dfWorld.tail(15)
# Out:
#           date  total_cases  total_deaths  new_cases  new_deaths
# 134 2020-08-14   20923528.0      754082.0   286951.0      9923.0
# 135 2020-08-15   21212689.0      760334.0   289161.0      6252.0
# 136 2020-08-16   21472436.0      765990.0   259747.0      5656.0
# 137 2020-08-17   21704807.0      770213.0   232371.0      4223.0
# 138 2020-08-18   21901190.0      774471.0   196383.0      4258.0
# 139 2020-08-19   22156098.0      781152.0   254908.0      6681.0
# 140 2020-08-20   22437231.0      787685.0   281133.0      6533.0
# 141 2020-08-21   22713395.0      794027.0   276164.0      6342.0
# 142 2020-08-22   22967096.0      799939.0   253701.0      5912.0
# 143 2020-08-23   23233865.0      805573.0   266769.0      5634.0
# 144 2020-08-24   23458521.0      808896.0   224656.0      3323.0
# 145 2020-08-25   23678420.0      813434.0   219899.0      4538.0
# 146 2020-08-26   23933380.0      819808.0   254960.0      6374.0
# 147 2020-08-27   24211468.0      826122.0   278088.0      6314.0
# 148 2020-08-28   24473843.0      832002.0   262375.0      5880.0

# %%
ads = dfWorld.loc[:,['date','new_cases']]
ads = ads.set_index('date')
ads.tail(15)
# Out:
#             new_cases
# date
# 2020-08-14   286951.0
# 2020-08-15   289161.0
# 2020-08-16   259747.0
# 2020-08-17   232371.0
# 2020-08-18   196383.0
# 2020-08-19   254908.0
# 2020-08-20   281133.0
# 2020-08-21   276164.0
# 2020-08-22   253701.0
# 2020-08-23   266769.0
# 2020-08-24   224656.0
# 2020-08-25   219899.0
# 2020-08-26   254960.0
# 2020-08-27   278088.0
# 2020-08-28   262375.0

# %%
currency = dfWorld.loc[:,['date','new_deaths']]
currency = currency.set_index('date')
currency.tail(15)
# Out:
#             new_deaths
# date
# 2020-08-14      9923.0
# 2020-08-15      6252.0
# 2020-08-16      5656.0
# 2020-08-17      4223.0
# 2020-08-18      4258.0
# 2020-08-19      6681.0
# 2020-08-20      6533.0
# 2020-08-21      6342.0
# 2020-08-22      5912.0
# 2020-08-23      5634.0
# 2020-08-24      3323.0
# 2020-08-25      4538.0
# 2020-08-26      6374.0
# 2020-08-27      6314.0
# 2020-08-28      5880.0

# %%
plt.figure(figsize=(19.20,10.80))
plt.plot(ads.new_cases)
plt.title('New Cases')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(19.20,10.80))
plt.plot(currency.new_deaths)
plt.title('New Deaths')
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error

# %%
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def moving_average(series, n):
    return np.average(series[-n:])

moving_average(currency, 7)
# Out:
# 5425.0

# %%
def plotMovingAverage(series, window, plot_intervals=False, scale=0.96, plot_anomalies=False):
    
    rolling_mean = series.rolling(window=window).mean()

    plt.figure(figsize=(19.20, 10.80))
    plt.title("Moving average\n window size = {}".format(window))
    plt.plot(rolling_mean, "r", label="Rolling mean trend")

    if plot_intervals:
        mae = mean_absolute_error(series[window:], rolling_mean[window:])
        deviation = np.std(series[window:] - rolling_mean[window:])
        lower_bond = rolling_mean - (mae + scale * deviation)
        upper_bond = rolling_mean + (mae + scale * deviation)
        plt.plot(upper_bond, "g--", label="Upper Bond / Lower Bond")
        plt.plot(lower_bond, "g--")
        
        if plot_anomalies:
            anomalies = pd.DataFrame(index=series.index, columns=series.columns)
            anomalies[series<lower_bond] = series[series<lower_bond]
            anomalies[series>upper_bond] = series[series>upper_bond]
            plt.plot(anomalies, "ro", markersize=10)
        
    plt.plot(series[window:], label="Actual values")
    plt.legend(loc="upper left")
    plt.grid(True)

# %%
plotMovingAverage(currency,24)

# %%
plotMovingAverage(ads, 4, plot_intervals=True)

# %%
plotMovingAverage(ads, 4, plot_intervals=True, plot_anomalies=True)

# %%
plotMovingAverage(currency, 4, plot_intervals=True, plot_anomalies=True)
