# %%
import pandas as pd
import numpy as np
import datetime as dt

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker

plt.rcParams.update({'font.size': 16})

# %%
pd.set_option('display.max_rows', 15)

# %%
# filename = '/home/davi/Documents/Python/Covid-19-Data/HIST_PAINEL_COVIDBR_04ago2020.xlsx'

# %%
#df = pd.read_excel('HIST_PAINEL_COVIDBR_04ago2020.xlsx')

# %%
df = pd.read_csv('caso_full.csv')
df['date'] = pd.to_datetime(df['date'])
df = df.dropna()
df
# Out:
#                 city  city_ibge_code       date  epidemiological_week  \
# 0          São Paulo       3550308.0 2020-02-25                     9
# 2          São Paulo       3550308.0 2020-02-26                     9
# 4          São Paulo       3550308.0 2020-02-27                     9
# 6          São Paulo       3550308.0 2020-02-28                     9
# 8          São Paulo       3550308.0 2020-02-29                     9
# ...              ...             ...        ...                   ...
# 481822    Tocantínia       1721109.0 2020-08-04                    32
# 481823      Tupirama       1721257.0 2020-08-04                    32
# 481824    Tupiratins       1721307.0 2020-08-04                    32
# 481825  Wanderlândia       1722081.0 2020-08-04                    32
# 481826       Xambioá       1722107.0 2020-08-04                    32
#
#         estimated_population_2019  is_last  is_repeated  \
# 0                      12252023.0    False        False
# 2                      12252023.0    False        False
# 4                      12252023.0    False        False
# 6                      12252023.0    False        False
# 8                      12252023.0    False        False
# ...                           ...      ...          ...
# 481822                     7545.0    False         True
# 481823                     1891.0    False         True
# 481824                     2671.0    False         True
# 481825                    11683.0    False         True
# 481826                    11540.0    False         True
#
#         last_available_confirmed  \
# 0                              1
# 2                              1
# 4                              1
# 6                              2
# 8                              2
# ...                          ...
# 481822                       222
# 481823                        23
# 481824                         6
# 481825                       158
# 481826                       565
#
#         last_available_confirmed_per_100k_inhabitants last_available_date  \
# 0                                             0.00816          2020-02-25
# 2                                             0.00816          2020-02-26
# 4                                             0.00816          2020-02-27
# 6                                             0.01632          2020-02-28
# 8                                             0.01632          2020-02-29
# ...                                               ...                 ...
# 481822                                     2942.34592          2020-08-03
# 481823                                     1216.28768          2020-08-03
# 481824                                      224.63497          2020-08-03
# 481825                                     1352.39236          2020-08-03
# 481826                                     4896.01386          2020-08-03
#
#         last_available_death_rate  last_available_deaths  order_for_place  \
# 0                          0.0000                      0                1
# 2                          0.0000                      0                2
# 4                          0.0000                      0                3
# 6                          0.0000                      0                4
# 8                          0.0000                      0                5
# ...                           ...                    ...              ...
# 481822                     0.0180                      4               78
# 481823                     0.0435                      1               74
# 481824                     0.0000                      0               74
# 481825                     0.0316                      5               99
# 481826                     0.0142                      8               88
#
#        place_type state  new_confirmed  new_deaths
# 0            city    SP              1           0
# 2            city    SP              0           0
# 4            city    SP              0           0
# 6            city    SP              1           0
# 8            city    SP              0           0
# ...           ...   ...            ...         ...
# 481822       city    TO              0           0
# 481823       city    TO              0           0
# 481824       city    TO              0           0
# 481825       city    TO              0           0
# 481826       city    TO              0           0
#
# [464796 rows x 17 columns]

# %%
# list(df.columns)

# %%
df = df.loc[:,['date', 'state', 'city', 'estimated_population_2019', 'last_available_confirmed', 'last_available_deaths', 'new_confirmed', 'new_deaths']]
df
# Out:
#              date state          city  estimated_population_2019  \
# 0      2020-02-25    SP     São Paulo                 12252023.0
# 2      2020-02-26    SP     São Paulo                 12252023.0
# 4      2020-02-27    SP     São Paulo                 12252023.0
# 6      2020-02-28    SP     São Paulo                 12252023.0
# 8      2020-02-29    SP     São Paulo                 12252023.0
# ...           ...   ...           ...                        ...
# 481822 2020-08-04    TO    Tocantínia                     7545.0
# 481823 2020-08-04    TO      Tupirama                     1891.0
# 481824 2020-08-04    TO    Tupiratins                     2671.0
# 481825 2020-08-04    TO  Wanderlândia                    11683.0
# 481826 2020-08-04    TO       Xambioá                    11540.0
#
#         last_available_confirmed  last_available_deaths  new_confirmed  \
# 0                              1                      0              1
# 2                              1                      0              0
# 4                              1                      0              0
# 6                              2                      0              1
# 8                              2                      0              0
# ...                          ...                    ...            ...
# 481822                       222                      4              0
# 481823                        23                      1              0
# 481824                         6                      0              0
# 481825                       158                      5              0
# 481826                       565                      8              0
#
#         new_deaths
# 0                0
# 2                0
# 4                0
# 6                0
# 8                0
# ...            ...
# 481822           0
# 481823           0
# 481824           0
# 481825           0
# 481826           0
#
# [464796 rows x 8 columns]

# %%
cities = set(df.loc[:, 'city'].values)

# %%
brStates = sorted(set(df.loc[:, 'state'].values))
brStates
# Out:
# ['AC',
#  'AL',
#  'AM',
#  'AP',
#  'BA',
#  'CE',
#  'DF',
#  'ES',
#  'GO',
#  'MA',
#  'MG',
#  'MS',
#  'MT',
#  'PA',
#  'PB',
#  'PE',
#  'PI',
#  'PR',
#  'RJ',
#  'RN',
#  'RO',
#  'RR',
#  'RS',
#  'SC',
#  'SE',
#  'SP',
#  'TO']

# %%
yesterday = pd.to_datetime('today') - pd.Timedelta(days=1)
yesterday
# Out:
# Timestamp('2020-08-04 01:29:04.046260')

# %%
dfToday = df[df['date'] > (pd.to_datetime("today") - pd.to_timedelta('2days'))]
dfToday
# Out:
#              date state          city  estimated_population_2019  \
# 476323 2020-08-04    AC    Acrelândia                    15256.0
# 476324 2020-08-04    AC  Assis Brasil                     7417.0
# 476325 2020-08-04    AC     Brasiléia                    26278.0
# 476326 2020-08-04    AC        Bujari                    10266.0
# 476327 2020-08-04    AC      Capixaba                    11733.0
# ...           ...   ...           ...                        ...
# 481822 2020-08-04    TO    Tocantínia                     7545.0
# 481823 2020-08-04    TO      Tupirama                     1891.0
# 481824 2020-08-04    TO    Tupiratins                     2671.0
# 481825 2020-08-04    TO  Wanderlândia                    11683.0
# 481826 2020-08-04    TO       Xambioá                    11540.0
#
#         last_available_confirmed  last_available_deaths  new_confirmed  \
# 476323                       293                      7              6
# 476324                       349                      8              9
# 476325                       834                     12              2
# 476326                       329                      5              4
# 476327                       226                      7             11
# ...                          ...                    ...            ...
# 481822                       222                      4              0
# 481823                        23                      1              0
# 481824                         6                      0              0
# 481825                       158                      5              0
# 481826                       565                      8              0
#
#         new_deaths
# 476323           0
# 476324           0
# 476325           1
# 476326           0
# 476327           0
# ...            ...
# 481822           0
# 481823           0
# 481824           0
# 481825           0
# 481826           0
#
# [5466 rows x 8 columns]
